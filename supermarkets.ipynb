# %%
import os 
os.listdir() #lists all the files and dirs.
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
import pandas
df = pandas.read_csv("supermarkets.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-041359ad752c> in <module>
# ----> 1 import pandas
#       2 df = pandas.read_csv("supermarkets.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas
df = pandas.read_csv("supermarkets.csv")

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1 = pandas.read_json("supermarkets.json")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_excel("supermarkets.xlsx",sheet_name= 0) #sheet_name is used to specify sheet in the excel sheet.
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %% [markdown]
# df4 = pandas.read_csv("FMP.xls")
# df4

# %%
df4 = pandas.read_excel("FMP.xls") # To load xls or xlsx file ,execute  pip install xlrd  
df4
# Out:
#    Scheme Code                      Scheme Name
# 0   AUG1846D13   HDFC FMP 1846D August 2013 (1)
# 1   AUG1875D13   HDFC FMP 1875D August 2013 (1)
# 2   JAN1175D14  HDFC FMP 1175D January 2014 (1)
# 3   FEB793D114  HDFC FMP 793D FEBRUARY 2014 (1)
# 4   MAR370D114     HDFC FMP 370D MARCH 2014 (1)
# ..         ...                              ...
# 61  MAR1145D18    HDFC FMP 1145D March 2018 (1)
# 62  APR1183D18    HDFC FMP 1183D April 2018 (1)
# 63  APR1181D18    HDFC FMP 1181D April 2018 (1)
# 64  APR1146D18    HDFC FMP 1146D April 2018 (1)
# 65  MAY097D118        HDFC FMP 97D May 2018 (1)
#
# [66 rows x 2 columns]

# %%
import pandas
df5 = pandas.read_csv("supermarkets-commas.txt")
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7 = df5.set_index("Address") #set_index will create a new Dataframe.
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.shape # shape method returns rows and column numbers in dataframe respectively.
# Out:
# (5, 4)

# %%
df7.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '332 Hill St', '3995 23rd St',
#        '1056 Sanchez St', 'Satwis clarinet'],
#       dtype='object', name='Address')

# %%
df7.columns
# Out:
# Index(['City', 'State', 'Country', 'Name', 'My Continent'], dtype='object')

# %%
df7["My Continent"] = df7.shape[0]*["North America"]
df7
# Out:
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
#
#                   My Continent
# Address
# 3666 21st St     North America
# 735 Dolores St   North America
# 332 Hill St      North America
# 3995 23rd St     North America
# 1056 Sanchez St  North America

# %%
df7["My Continent"] = df7["Country"] + "," + ["North America"]
df7
# Out:
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
#
#                       My Continent
# Address
# 3666 21st St     USA,North America
# 735 Dolores St   USA,North America
# 332 Hill St      USA,North America
# 3995 23rd St     USA,North America
# 1056 Sanchez St  USA,North America

# %%
df7_t = df7.T # Transpose method converts columns into rwos and vice versa.
df7_t
# Out:
# Address            3666 21st St     735 Dolores St        332 Hill St  \
# City              San Francisco      San Francisco      San Francisco
# State                  CA 94114           CA 94119   California 94114
# Country                     USA                USA                USA
# Name                    Madeira        Bready Shop        Super River
# My Continent  USA,North America  USA,North America  USA,North America
#
# Address            3995 23rd St    1056 Sanchez St
# City              San Francisco      San Francisco
# State                  CA 94114         California
# Country                     USA                USA
# Name                 Ben's Shop            Sanchez
# My Continent  USA,North America  USA,North America

# %%
df7_t["Satwis clarinet"] = ["Bangalore","Karnataka","India","Name","India,Asia"]
df7_t
# Out:
# Address            3666 21st St     735 Dolores St        332 Hill St  \
# City              San Francisco      San Francisco      San Francisco
# State                  CA 94114           CA 94119   California 94114
# Country                     USA                USA                USA
# Name                    Madeira        Bready Shop        Super River
# My Continent  USA,North America  USA,North America  USA,North America
#
# Address            3995 23rd St    1056 Sanchez St Satwis clarinet
# City              San Francisco      San Francisco       Bangalore
# State                  CA 94114         California       Karnataka
# Country                     USA                USA           India
# Name                 Ben's Shop            Sanchez            Name
# My Continent  USA,North America  USA,North America      India,Asia

# %%
df7 = df7_t.T
df7
# Out:
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# Satwis clarinet      Bangalore         Karnataka   India         Name
#
#                       My Continent
# Address
# 3666 21st St     USA,North America
# 735 Dolores St   USA,North America
# 332 Hill St      USA,North America
# 3995 23rd St     USA,North America
# 1056 Sanchez St  USA,North America
# Satwis clarinet         India,Asia

# %%
df7_t = df7.T
df7_t
# Out:
# Address            3666 21st St     735 Dolores St        332 Hill St  \
# City              San Francisco      San Francisco      San Francisco
# State                  CA 94114           CA 94119   California 94114
# Country                     USA                USA                USA
# Name                    Madeira        Bready Shop        Super River
# My Continent  USA,North America  USA,North America  USA,North America
#
# Address            3995 23rd St    1056 Sanchez St Satwis clarinet
# City              San Francisco      San Francisco       Bangalore
# State                  CA 94114         California       Karnataka
# Country                     USA                USA           India
# Name                 Ben's Shop            Sanchez            Name
# My Continent  USA,North America  USA,North America      India,Asia

# %%
df7_t["5522 Miami blvd"] = ["NYC","NY","USA","dasadadd","USA,North America"]
df7_t
# Out:
# Address            3666 21st St     735 Dolores St        332 Hill St  \
# City              San Francisco      San Francisco      San Francisco
# State                  CA 94114           CA 94119   California 94114
# Country                     USA                USA                USA
# Name                    Madeira        Bready Shop        Super River
# My Continent  USA,North America  USA,North America  USA,North America
#
# Address            3995 23rd St    1056 Sanchez St Satwis clarinet  \
# City              San Francisco      San Francisco       Bangalore
# State                  CA 94114         California       Karnataka
# Country                     USA                USA           India
# Name                 Ben's Shop            Sanchez            Name
# My Continent  USA,North America  USA,North America      India,Asia
#
# Address         5522 Miami blvd
# City                        NYC
# State                        NY
# Country                     USA
# ...

# %%
df7 = df7_t.T
df7
# Out:
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# Satwis clarinet      Bangalore         Karnataka   India         Name
# 5522 Miami blvd            NYC                NY     USA     dasadadd
#
#                       My Continent
# Address
# 3666 21st St     USA,North America
# 735 Dolores St   USA,North America
# 332 Hill St      USA,North America
# 3995 23rd St     USA,North America
# 1056 Sanchez St  USA,North America
# Satwis clarinet         India,Asia
# 5522 Miami blvd  USA,North America

# %%
df7 = df7.loc["3666 21st St":"1056 Sanchez St","City":"Name"]
df7
# Out:
#                           City             State Country         Name
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez

# %%
df7.loc[:,"Country"]
# Out:
# Address
# 3666 21st St       USA
# 735 Dolores St     USA
# 332 Hill St        USA
# 3995 23rd St       USA
# 1056 Sanchez St    USA
# Name: Country, dtype: object

# %%
df10 = df7.drop(df7.index[0:4],0) # drop rows using index ,index represents rows and column represents columns in dataframe
df10
# Out:
#                           City       State Country     Name
# Address
# 1056 Sanchez St  San Francisco  California     USA  Sanchez

# %%
df13 = df7.drop(df7.index[0:1],0)
df13
# Out:
#                           City             State Country         Name
# Address
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez

# %%
df14 = df7.drop(df7.columns[2:5],1)
df14
# Out:
#                           City             State
# Address
# 3666 21st St     San Francisco          CA 94114
# 735 Dolores St   San Francisco          CA 94119
# 332 Hill St      San Francisco  California 94114
# 3995 23rd St     San Francisco          CA 94114
# 1056 Sanchez St  San Francisco        California

# %%
df11 = df7.drop(df7.columns[0:2],1)
df11 #drop columns
# Out:
#                 Country         Name
# Address
# 3666 21st St        USA      Madeira
# 735 Dolores St      USA  Bready Shop
# 332 Hill St         USA  Super River
# 3995 23rd St        USA   Ben's Shop
# 1056 Sanchez St     USA      Sanchez

# %%
df8 = pandas.read_csv("data.txt",header=None)
df8
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df8.columns = ["ID","Address","City","State","Zip","Country","Employees"]
df8
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-874f9de95017> in <module>
# ----> 1 df8.columns = ["ID","Address","City","State","Zip","Country","Employees"]
#       2 df8
#
# c:\users\sutha\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# c:\users\sutha\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
# ...

# %%
df8.shape
# Out:
# (2, 4)

# %%
df8["My Continent"] = df8.shape[0]*["North America"]
df8
# Out:
#    Country          Name  Employees   My Continent
# ID
# 2      USA   Bready Shop         15  North America
# 3      USA   Super River         25  North America

# %%
df8
# Out:
#             Address           City             State  Zip      Country  \
# ID
# 1      3666 21st St  San Francisco          CA 94114  USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119  USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114  USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California  USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114  USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df9 = df8.set_index("Zip",drop=False)
df9
# Out:
#              Address             State  Zip      Country  Employees
# Zip
# USA     3666 21st St          CA 94114  USA      Madeira          8
# USA   735 Dolores St          CA 94119  USA  Bready Shop         15
# USA      332 Hill St  California 94114  USA  Super River         25
# USA     3995 23rd St          CA 94114  USA   Ben's Shop         10
# USA  1056 Sanchez St        California  USA      Sanchez         12
# USA  551 Alvarado St          CA 94114  USA   Richvalley         20

# %%
df6 = pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df6
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7 = df6.set_index("ID")
df7
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df10 = df8.iloc[1:5,:]
df10
# Out:
#    Country          Name  Employees
# ID
# 3      USA   Super River         25

# %%
df8=df7.iloc[1:3,3:7]
df8
# Out:
#    Country          Name  Employees
# ID
# 2      USA   Bready Shop         15
# 3      USA   Super River         25

# %%
import geopy
dir(geopy)
from geopy.geocoders import ArcGIS
nom = ArcGIS()
n = nom.geocode("Vrajvihar apartment,ghodasar,ahmedabad-380050")

# %%
n.longitude
# Out:
# 72.61585744823708

# %%
n.latitude
# Out:
# 22.984702931444406

# %%
import geopy
from geopy.geocoders import ArcGIS 
nom = ArcGIS()
nom.geocode("Satwis Clarinet,Bangalore,India")
# Out:
# Location(SATWIS CLARINET, S Shivarudrappa Road, Horamavu, Bangalore, Bengaluru, Karnataka, 560043, (13.035953462115527, 77.66752162101102, 0.0))

# %%
import pandas 
df = pandas.read_csv("supermarkets.csv")
df["Address"] = df["Address"] + "," + df["City"] + "," + df["State"] + "," + df["Country"]
df
# Out:
#    ID                                         Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114,USA  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119,USA  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California,USA  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                         Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114,USA  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119,USA  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California,USA  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# 0  (3666 21st St, San Francisco, California, 9411...
# ...

# %%
df["Coordinates"][0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.7564496899993, -122.42936434915458, 0.0))

# %%
type(df["Coordinates"][0])
# Out:
# geopy.location.Location

# %%
dir(geopy.location.Location)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '_address',
#  '_point',
#  '_raw',
#  '_tuple',
#  'address',
#  'altitude',
#  'latitude',
#  'longitude',
#  'point',
#  'raw']

# %%
df["Coordinates"][1].latitude
# Out:
# 37.7577961290611

# %%
df["Coordinates"][1].longitude
# Out:
# -122.42559668301706

# %%
df["Coordinates"][1].address
# Out:
# '735 Dolores St, San Francisco, California, 94110'

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x : x.latitude if x!= None else None)
df
# Out:
#    ID                                         Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114,USA  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119,USA  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California,USA  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude
# ...

# %%
type(df["Coordinates"])
# Out:
# pandas.core.series.Series

# %%
df["Longitude"]  = df["Coordinates"].apply(lambda y : y.longitude if y != None else None)
df
# Out:
#    ID                                         Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114,USA  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119,USA  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California,USA  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...

# %%
import geopy
import pandas
from geopy.geocoders import ArcGIS
nom = ArcGIS()
df = pandas.read_csv("supermarkets.csv")
df["Address"] = df["Address"] + "," + df["City"] + "," + df["State"] + "," +df["Country"]
df["Coordinates"] = df["Address"].apply(nom.geocode)
long = df.Coordinates[0].longitude
lat = df.Coordinates[0].latitude
address = df.Coordinates[0].address
address,long,lat
# Out:
# ('3666 21st St, San Francisco, California, 94114',
#  -122.42936434915458,
#  37.7564496899993)
